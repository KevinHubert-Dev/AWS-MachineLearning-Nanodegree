# %% [markdown]
# # Detecting Payment Card Fraud
#
# In this section, we'll look at a credit card fraud detection dataset, and build a binary classification model that can identify transactions as either fraudulent or valid, based on provided, *historical* data. In a [2016 study](https://nilsonreport.com/upload/content_promo/The_Nilson_Report_10-17-2016.pdf), it was estimated that credit card fraud was responsible for over 20 billion dollars in loss, worldwide. Accurately detecting cases of fraud is an ongoing area of research.
#
# <img src=notebook_ims/fraud_detection.png width=50% />
#
# ### Labeled Data
#
# The payment fraud data set (Dal Pozzolo et al. 2015) was downloaded from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data). This has features and labels for thousands of credit card transactions, each of which is labeled as fraudulent or valid. In this notebook, we'd like to train a model based on the features of these transactions so that we can predict risky or fraudulent transactions in the future.
#
# ### Binary Classification
#
# Since we have true labels to aim for, we'll take a **supervised learning** approach and train a binary classifier to sort data into one of our two transaction classes: fraudulent or valid.  We'll train a model on training data and see how well it generalizes on some test data.
#
# The notebook will be broken down into a few steps:
# * Loading and exploring the data
# * Splitting the data into train/test sets
# * Defining and training a LinearLearner, binary classifier
# * Making improvements on the model
# * Evaluating and comparing model test performance
#
# ### Making Improvements
#
# A lot of this notebook will focus on making improvements, as discussed in [this SageMaker blog post](https://aws.amazon.com/blogs/machine-learning/train-faster-more-flexible-models-with-amazon-sagemaker-linear-learner/). Specifically, we'll address techniques for:
#
# 1. **Tuning a model's hyperparameters** and aiming for a specific metric, such as high recall or precision.
# 2. **Managing class imbalance**, which is when we have many more training examples in one class than another (in this case, many more valid transactions than fraudulent).
#
# ---

# %% [markdown]
# First, import the usual resources.

# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 

import boto3
import sagemaker
from sagemaker import get_execution_role

# %matplotlib inline

# %% [markdown]
# I'm storing my **SageMaker variables** in the next cell:
# * sagemaker_session: The SageMaker session we'll use for training models.
# * bucket: The name of the default S3 bucket that we'll use for data storage.
# * role: The IAM role that defines our data and model permissions.

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Loading and Exploring the Data
#
# Next, I am loading the data and unzipping the data in the file `creditcardfraud.zip`. This directory will hold one csv file of all the transaction data, `creditcard.csv`.
#
# As in previous notebooks, it's important to look at the distribution of data since this will inform how we develop a fraud detection model. We'll want to know: How many data points we have to work with, the number and type of features, and finally, the distribution of data over the classes (valid or fraudulent).

# %%
# only have to run once
# !wget https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
# !unzip creditcardfraud
# Out:
# --2021-01-01 14:42:45--  https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.88.149
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.88.149|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip.2’
#
# creditcardfraud.zip  60%[===========>        ]  39.66M  3.85MB/s    eta 7s     ^C
# Archive:  creditcardfraud.zip
# replace creditcard.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# read in the csv file
local_data = 'creditcard.csv'

# print out some data
transaction_df = pd.read_csv(local_data)
print('Data shape (rows, cols): ', transaction_df.shape)
print()
transaction_df.head()
# Out:
# Data shape (rows, cols):  (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### EXERCISE: Calculate the percentage of fraudulent data
#
# Take a look at the distribution of this transaction data over the classes, valid and fraudulent.
#
# Complete the function `fraudulent_percentage`, below. Count up the number of data points in each class and calculate the *percentage* of the data points that are fraudulent.

# %%
# Calculate the fraction of data points that are fraudulent
def fraudulent_percentage(transaction_df):
    '''Calculate the fraction of all data points that have a 'Class' label of 1; fraudulent.
       :param transaction_df: Dataframe of all transaction data points; has a column 'Class'
       :return: A fractional percentage of fraudulent data points/all points
    '''
    classes = transaction_df['Class'].value_counts()
    valid = classes[0]
    fraud = classes[1]
    return fraud / (valid + fraud)

# %% [markdown]
# Test out your code by calling your function and printing the result.

# %%
# call the function to calculate the fraud percentage
fraud_percentage = fraudulent_percentage(transaction_df)

print('Fraudulent percentage = ', fraud_percentage)
print('Total # of fraudulent pts: ', fraud_percentage*transaction_df.shape[0])
print('Out of (total) pts: ', transaction_df.shape[0])
# Out:
# Fraudulent percentage =  0.001727485630620034
# Total # of fraudulent pts:  492.0
# Out of (total) pts:  284807

# %% [markdown]
# ### EXERCISE: Split into train/test datasets
#
# In this example, we'll want to evaluate the performance of a fraud classifier; training it on some training data and testing it on *test data* that it did not see during the training process. So, we'll need to split the data into separate training and test sets.
#
# Complete the `train_test_split` function, below. This function should:
# * Shuffle the transaction data, randomly
# * Split it into two sets according to the parameter `train_frac`
# * Get train/test features and labels
# * Return the tuples: (train_features, train_labels), (test_features, test_labels)

# %%
from sklearn.utils import shuffle

# split into train/test
def train_test_split(transaction_df, train_frac= 0.7, seed=1):
    '''Shuffle the data and randomly split into train and test sets;
       separate the class labels (the column in transaction_df) from the features.
       :param df: Dataframe of all credit card transaction data
       :param train_frac: The decimal fraction of data that should be training data
       :param seed: Random seed for shuffling and reproducibility, default = 1
       :return: Two tuples (in order): (train_features, train_labels), (test_features, test_labels)
       '''
    if (train_frac < 0.0 or train_frac > 1.0):
        raise Exception("train_frac needs to be in range of 0.0 - 1.0")
    
    matrix = np.array(transaction_df)
    np.random.seed = seed
    np.random.shuffle(matrix)
    
    entries = matrix.shape[0]
    
    train_amount = int(entries * train_frac)
    test_amount = entries - train_amount
    
    # shuffle and split the data
    train_features = matrix[:train_amount, :-1]
    
    train_labels = matrix[:train_amount, -1]
    test_features = matrix[train_amount:, :-1]
    test_labels = matrix[train_amount:, -1]
    
    return (train_features, train_labels), (test_features, test_labels)

# %% [markdown]
# ### Test Cell
#
# In the cells below, I'm creating the train/test data and checking to see that result makes sense. The tests below test that the above function splits the data into the expected number of points and that the labels are indeed, class labels (0, 1).

# %%
# get train/test data
(train_features, train_labels), (test_features, test_labels) = train_test_split(transaction_df, train_frac=0.7)

transaction_df = None

# %%
# manual test

# for a split of 0.7:0.3 there should be ~2.33x as many training as test pts
print('Training data pts: ', len(train_features))
print('Test data pts: ', len(test_features))
print()

# take a look at first item and see that it aligns with first row of data
print('First item: \n', train_features[0])
print('Label: ', train_labels[0])
print()

# test split
assert len(train_features) > 2.333*len(test_features), \
        'Unexpected number of train/test points for a train_frac=0.7'
# test labels
assert np.all(train_labels)== 0 or np.all(train_labels)== 1, \
        'Train labels should be 0s or 1s.'
assert np.all(test_labels)== 0 or np.all(test_labels)== 1, \
        'Test labels should be 0s or 1s.'
print('Tests passed!')
# Out:
# Training data pts:  199364
# Test data pts:  85443
#
# First item:
#  [ 1.49488000e+05  2.04473304e+00  1.34528191e-01 -1.79904029e+00
#   2.16784765e-01  7.08062156e-01 -2.82286723e-01  1.03448612e-01
#  -7.90178580e-02  1.60665070e-01 -2.35495687e-01  1.01339158e+00
#   1.08124059e+00  6.43235975e-01 -7.82596482e-01 -4.92915177e-01
#   5.14379750e-01  1.33206195e-01  1.22922183e-01  3.81193296e-01
#  -1.01480447e-01 -3.19891678e-01 -8.14526757e-01  2.88840058e-01
#   1.43074943e-01 -2.41900267e-01  1.76142914e-01 -5.97679087e-02
#  -4.29240479e-02  1.98000000e+00]
# Label:  0.0
#
# Tests passed!

# %% [markdown]
# ---
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# In this notebook, you'll define and train the SageMaker, built-in algorithm, [LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html).
#
# A LinearLearner has two main applications:
# 1. For regression tasks in which a linear line is fit to some data points, and you want to produce a predicted output value given some data point (example: predicting house prices given square area).
# 2. For binary classification, in which a line is separating two classes of data and effectively outputs labels; either 1 for data that falls above the line or 0 for points that fall on or below the line.
#
# <img src='notebook_ims/linear_separator.png' width=50% />
#
# In this case, we'll be using it for case 2, and we'll train it to separate data into our two classes: valid or fraudulent.

# %% [markdown]
# ### EXERCISE: Create a LinearLearner Estimator
#
# You've had some practice instantiating built-in models in SageMaker. All estimators require some constructor arguments to be passed in. See if you can complete this task, instantiating a LinearLearner estimator, using only the [LinearLearner documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html) as a resource. This takes in a lot of arguments, but not all are required. My suggestion is to start with a simple model, utilizing default values where applicable. Later, we will discuss some specific hyperparameters and their use cases.
#
# #### Instance Types
#
# It is suggested that you use instances that are available in the free tier of usage: `'ml.c4.xlarge'` for training and `'ml.t2.medium'` for deployment.

# %%
# import LinearLearner
from sagemaker import LinearLearner

# use s3 to save model
prefix = 'creditcard'
output_path = 's3://{}/{}'.format(bucket, prefix)

# instantiate LinearLearner
linear_learner = LinearLearner(role=role,
                             instance_count=1,
                             instance_type='ml.c4.xlarge',
                             predictor_type='binary_classifier',
                             output_path=output_path,
                             sagemaker_session=sagemaker_session,
                             epochs=10)

# %% [markdown]
# ### EXERCISE: Convert data into a RecordSet format
#
# Next, prepare the data for a built-in model by converting the train features and labels into numpy array's of float values. Then you can use the [record_set function](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner.record_set) to format the data as a RecordSet and prepare it for training!

# %%
# create RecordSet of training data

# convert features/labels to numpy
train_x_np = train_features.astype('float32')
train_y_np = train_labels.astype('float32')

# create RecordSet
formatted_train_data = linear_learner.record_set(train_x_np, labels=train_y_np)

# %% [markdown]
# ### EXERCISE: Train the Estimator
#
# After instantiating your estimator, train it with a call to `.fit()`, passing in the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_learner.fit(formatted_train_data)
formatted_train_data = None
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-01-02 00:36:46 Starting - Starting the training job...
# 2021-01-02 00:36:50 Starting - Launching requested ML instancesProfilerReport-1609547805: InProgress
# ......
# 2021-01-02 00:38:11 Starting - Preparing the instances for training......
# 2021-01-02 00:39:02 Downloading - Downloading input data
# 2021-01-02 00:39:02 Training - Downloading the training image.....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [01/02/2021 00:39:59 INFO 140060524631872] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/02/2021 00:39:59 INFO 140060524631872] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'10', u'feature_dim': u'30', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier'}
# [01/02/2021 00:39:59 INFO 140060524631872] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'10', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/02/2021 00:39:59 WARNING 140060524631872] Loggers have already been setup.
# Process 1 is a worker.
# [01/02/2021 00:39:59 INFO 140060524631872] Using default worker.
# [01/02/2021 00:39:59 INFO 140060524631872] Checkpoint loading and saving are disabled.
# [2021-01-02 00:39:59.258] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 29, "num_examples": 1, "num_bytes": 168000}
# [01/02/2021 00:39:59 INFO 140060524631872] Create Store: local
# [2021-01-02 00:39:59.334] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 75, "num_examples": 11, "num_bytes": 1848000}
# [01/02/2021 00:39:59 INFO 140060524631872] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f6202551d50>
# [01/02/2021 00:39:59 INFO 140060524631872] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7434254e+04 1.9490141e+00 1.6077511e+00 1.5218714e+00 1.4257979e+00
#  1.3810602e+00 1.3367766e+00 1.2290752e+00 1.0719861e+00 1.0964193e+00
#  1.1155506e+00 1.0274336e+00 1.0482663e+00 9.9833149e-01 9.7970086e-01
#  9.1996390e-01 8.9201581e-01 8.7713647e-01 8.4200925e-01 8.2139194e-01
#  6.8980324e-01 6.8706536e-01 7.1164435e-01 5.7642090e-01 6.0646504e-01
#  5.1390278e-01 4.8457688e-01 3.9975840e-01 3.1006801e-01 2.2592365e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.43968125e+04  1.25075504e-02 -1.13726244e-03  4.85565141e-03
#   2.11084858e-02 -1.78897008e-03  1.49521586e-02 -1.77812204e-02
#   1.69748515e-02  3.32083087e-03  2.19379552e-03  4.49634111e-03
#  -1.61974784e-02  1.93719449e-03  6.95569115e-03 -6.79877587e-03
#   1.90204801e-03 -1.08608175e-02 -7.65408156e-03  9.77676548e-03
#   1.45532284e-03  3.35761392e-03  7.45437667e-03  3.35630495e-04
#  -3.39410105e-03  4.08239989e-03  8.39966908e-03 -3.46532161e-03
#  -1.17302523e-03  8.52265015e+01]
# <NDArray 30 @cpu(0)>}
# [01/02/2021 00:39:59 INFO 140060524631872] nvidia-smi took: 0.0252277851105 secs to identify 0 gpus
# [01/02/2021 00:39:59 INFO 140060524631872] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "

#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012210373840140338, "sum": 0.012210373840140338, "min": 0.012210373840140338}}, "EndTime": 1609548062.373964, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1609548062.373957}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012240789415848314, "sum": 0.012240789415848314, "min": 0.012240789415848314}}, "EndTime": 1609548062.37399, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1609548062.373983}
#
# [01/02/2021 00:41:02 INFO 140060524631872] #quality_metric: host=algo-1, epoch=9, train binary_classification_cross_entropy_objective <loss>=0.00515898198638
# [01/02/2021 00:41:02 INFO 140060524631872] #early_stopping_criteria_metric: host=algo-1, epoch=9, criteria=binary_classification_cross_entropy_objective, value=0.00430784524281
# [01/02/2021 00:41:02 INFO 140060524631872] Saving model for epoch: 9
# [01/02/2021 00:41:02 INFO 140060524631872] Saved checkpoint to "/tmp/tmpnirk1u/mx-mod-0000.params"
# [01/02/2021 00:41:02 INFO 140060524631872] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 2012, "sum": 2012.0, "min": 2012}, "Total Records Seen": {"count": 1, "max": 2005640, "sum": 2005640.0, "min": 2005640}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1609548062.380904, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1609548056.331743}
#
# [01/02/2021 00:41:02 INFO 140060524631872] #throughput_metric: host=algo-1, train throughput=32956.6432829 records/second
# [01/02/2021 00:41:02 WARNING 140060524631872] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/02/2021 00:41:02 WARNING 140060524631872] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-01-02 00:41:02.391] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 23, "duration": 8, "num_examples": 1, "num_bytes": 168000}
# [2021-01-02 00:41:03.033] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 640, "num_examples": 200, "num_bytes": 33493152}
# [2021-01-02 00:41:03.805] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 28, "duration": 701, "num_examples": 200, "num_bytes": 33493152}
# [01/02/2021 00:41:03 INFO 140060524631872] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.004057385171289818)
# [01/02/2021 00:41:03 INFO 140060524631872] #train_score (algo-1) : ('binary_classification_accuracy', 0.9991824000321021)
# [01/02/2021 00:41:03 INFO 140060524631872] #train_score (algo-1) : ('binary_f_1.000', 0.7400318979266348)
# [01/02/2021 00:41:03 INFO 140060524631872] #train_score (algo-1) : ('precision', 0.7759197324414716)
# [01/02/2021 00:41:03 INFO 140060524631872] #train_score (algo-1) : ('recall', 0.7073170731707317)
# [01/02/2021 00:41:03 INFO 140060524631872] #train_score (algo-1) : ('roc_auc_score', 0.9796764459573192)
# [01/02/2021 00:41:03 INFO 140060524631872] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00405738517129
# [01/02/2021 00:41:03 INFO 140060524631872] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.999182400032
# [01/02/2021 00:41:03 INFO 140060524631872] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.740031897927
# [01/02/2021 00:41:03 INFO 140060524631872] #quality_metric: host=algo-1, train precision <score>=0.775919732441
# [01/02/2021 00:41:03 INFO 140060524631872] #quality_metric: host=algo-1, train recall <score>=0.707317073171
# [01/02/2021 00:41:03 INFO 140060524631872] #quality_metric: host=algo-1, train roc_auc_score <score>=0.979676445957
# [01/02/2021 00:41:03 INFO 140060524631872] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [01/02/2021 00:41:03 INFO 140060524631872] Saved checkpoint to "/tmp/tmpo9IOML/mx-mod-0000.params"
# [01/02/2021 00:41:03 INFO 140060524631872] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 64843.88184547424, "sum": 64843.88184547424, "min": 64843.88184547424}, "finalize.time": {"count": 1, "max": 1481.916904449463, "sum": 1481.916904449463, "min": 1481.916904449463}, "initialize.time": {"count": 1, "max": 209.46502685546875, "sum": 209.46502685546875, "min": 209.46502685546875}, "check_early_stopping.time": {"count": 10, "max": 0.9229183197021484, "sum": 6.544589996337891, "min": 0.19097328186035156}, "setuptime": {"count": 1, "max": 23.59294891357422, "sum": 23.59294891357422, "min": 23.59294891357422}, "update.time": {"count": 10, "max": 6724.623918533325, "sum": 62896.9612121582, "min": 5925.309896469116}, "epochs": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1609548063.868368, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1609547999.228685}
#
# Training seconds: 140
# Billable seconds: 140
# CPU times: user 687 ms, sys: 35.4 ms, total: 722 ms
# Wall time: 4min 42s

# %% [markdown]
# ### EXERCISE: Deploy the trained model
#
# Deploy your model to create a predictor. We'll use this to make predictions on our test data and evaluate the model.

# %%
# %%time 
# deploy and create a predictor
linear_predictor = linear_learner.deploy(initial_instance_count=1, instance_type='ml.c4.xlarge')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------!CPU times: user 246 ms, sys: 21.3 ms, total: 267 ms
# Wall time: 6min 31s

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to the test data.
#
# According to the deployed [predictor documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearnerPredictor), this predictor expects an `ndarray` of input features and returns a list of Records.
# > "The prediction is stored in the "predicted_label" key of the `Record.label` field."
#
# Let's first test our model on just one test point, to see the resulting list.

# %%
# test one prediction
test_x_np = test_features.astype('float32')
result = linear_predictor.predict(test_x_np[0])

test_x_np = None

print(result)
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 2.575761936896015e-05
#     }
#   }
# }
# ]

# %% [markdown]
# ### Helper function for evaluation
#
#
# The provided function below, takes in a deployed predictor, some test features and labels, and returns a dictionary of metrics; calculating false negatives and positives as well as recall, precision, and accuracy.

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    print(prediction_batches)
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %% [markdown]
# ### Test Results
#
# The cell below runs the `evaluate` function.
#
# The code assumes that you have a defined `predictor` and `test_features` and `test_labels` from previously-run cells.

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# prediction (col)    0.0  1.0
# actual (row)
# 0.0               85258   37
# 1.0                  41  107
#
# Recall:     0.723
# Precision:  0.743
# Accuracy:   0.999

# %% [markdown]
# ## Delete the Endpoint
#
# I've added a convenience function to delete prediction endpoints after we're done with them. And if you're done evaluating the model, you should delete your model endpoint!

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2021-01-02-00-41-28-607

# %% [markdown]
# ---
#
# # Model Improvements
#
# The default LinearLearner got a high accuracy, but still classified fraudulent and valid data points incorrectly. Specifically classifying more than 30 points as false negatives (incorrectly labeled, fraudulent transactions), and a little over 30 points as false positives (incorrectly labeled, valid transactions). Let's think about what, during training, could cause this behavior and what we could improve.
#
# **1. Model optimization**
# * If we imagine that we are designing this model for use in a bank application, we know that users do *not* want any valid transactions to be categorized as fraudulent. That is, we want to have as few **false positives** (0s classified as 1s) as possible.
# * On the other hand, if our bank manager asks for an application that will catch almost *all* cases of fraud, even if it means a higher number of false positives, then we'd want as few **false negatives** as possible.
# * To train according to specific product demands and goals, we do not want to optimize for accuracy only. Instead, we want to optimize for a metric that can help us decrease the number of false positives or negatives.
#
# <img src='notebook_ims/precision_recall.png' width=40% />
#
# In this notebook, we'll look at different cases for tuning a model and make an optimization decision, accordingly.
#
# **2. Imbalanced training data**
# * At the start of this notebook, we saw that only about 0.17% of the training data was labeled as fraudulent. So, even if a model labels **all** of our data as valid, it will still have a high accuracy.
# * This may result in some overfitting towards valid data, which accounts for some **false negatives**; cases in which fraudulent data (1) is incorrectly characterized as valid (0).
#
# So, let's address these issues in order; first, tuning our model and optimizing for a specific metric during training, and second, accounting for class imbalance in the training set.

# %% [markdown]
# ## Improvement: Model Tuning
#
# Optimizing according to a specific metric is called **model tuning**, and SageMaker provides a number of ways to automatically tune a model.
#
#
# ### Create a LinearLearner and tune for higher precision
#
# **Scenario:**
# * A bank has asked you to build a model that detects cases of fraud with an accuracy of about 85%.
#
# In this case, we want to build a model that has as many true positives and as few false negatives, as possible. This corresponds to a model with a high **recall**: true positives / (true positives + false negatives).
#
# To aim for a specific metric, LinearLearner offers the hyperparameter `binary_classifier_model_selection_criteria`, which is the model evaluation criteria for the training dataset. A reference to this parameter is in [LinearLearner's documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner). We'll also have to further specify the exact value we want to aim for; read more about the details of the parameters, [here](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html).
#
# I will assume that performance on a training set will be within about 5% of the performance on a test set. So, for a recall of about 85%, I'll aim for a bit higher, 90%.

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### Train the tuned estimator
#
# Fit the new, tuned estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-01-02 01:09:33 Starting - Starting the training job...
# 2021-01-02 01:09:56 Starting - Launching requested ML instancesProfilerReport-1609549773: InProgress
# ......
# 2021-01-02 01:10:57 Starting - Preparing the instances for training.........
# 2021-01-02 01:12:21 Downloading - Downloading input data
# 2021-01-02 01:12:21 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [01/02/2021 01:12:46 INFO 140066162063168] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/02/2021 01:12:46 INFO 140066162063168] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'feature_dim': u'30', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [01/02/2021 01:12:46 INFO 140066162063168] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/02/2021 01:12:46 WARNING 140066162063168] Loggers have already been setup.
# Process 1 is a worker.
# [01/02/2021 01:12:46 INFO 140066162063168] Using default worker.
# [01/02/2021 01:12:46 INFO 140066162063168] Checkpoint loading and saving are disabled.
# [2021-01-02 01:12:46.944] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 28, "num_examples": 1, "num_bytes": 168000}
# [01/02/2021 01:12:46 INFO 140066162063168] Create Store: local
# [2021-01-02 01:12:47.031] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 85, "num_examples": 11, "num_bytes": 1848000}
# [01/02/2021 01:12:47 INFO 140066162063168] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f6352b5de50>
# [01/02/2021 01:12:47 INFO 140066162063168] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7562227e+04 1.8698826e+00 1.5398437e+00 1.4669231e+00 1.3983092e+00
#  1.3596656e+00 1.3372819e+00 1.2142768e+00 1.0664711e+00 1.0869697e+00
#  1.0642679e+00 1.0180734e+00 1.0014011e+00 9.9890339e-01 9.4154650e-01
#  9.0477407e-01 8.6453688e-01 8.3226335e-01 8.3712864e-01 8.1374246e-01
#  7.0363200e-01 6.9986749e-01 7.3282444e-01 5.9232694e-01 6.0836059e-01
#  5.2394670e-01 4.7785282e-01 3.8357860e-01 3.1198832e-01 2.3838838e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
#
"Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.390177}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011989598082537627, "sum": 0.011989598082537627, "min": 0.011989598082537627}}, "EndTime": 1609550058.390252, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.390236}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012788953238396189, "sum": 0.012788953238396189, "min": 0.012788953238396189}}, "EndTime": 1609550058.390303, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.390288}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01271531706299614, "sum": 0.01271531706299614, "min": 0.01271531706299614}}, "EndTime": 1609550058.390357, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.39034}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012788877358987703, "sum": 0.012788877358987703, "min": 0.012788877358987703}}, "EndTime": 1609550058.390411, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.390395}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01271567976474762, "sum": 0.01271567976474762, "min": 0.01271567976474762}}, "EndTime": 1609550058.390469, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.390453}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012720538020733014, "sum": 0.012720538020733014, "min": 0.012720538020733014}}, "EndTime": 1609550058.390532, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.390515}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012786625876498581, "sum": 0.012786625876498581, "min": 0.012786625876498581}}, "EndTime": 1609550058.390597, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.390579}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012720980499257994, "sum": 0.012720980499257994, "min": 0.012720980499257994}}, "EndTime": 1609550058.390659, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.390642}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012787530661827355, "sum": 0.012787530661827355, "min": 0.012787530661827355}}, "EndTime": 1609550058.390719, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550058.390704}
#
# [01/02/2021 01:14:18 INFO 140066162063168] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.00470003608423
# [01/02/2021 01:14:18 INFO 140066162063168] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.00394929827458
# [01/02/2021 01:14:18 INFO 140066162063168] Epoch 14: Loss improved. Updating best model
# [01/02/2021 01:14:18 INFO 140066162063168] Saving model for epoch: 14
# [01/02/2021 01:14:18 INFO 140066162063168] Saved checkpoint to "/tmp/tmpn0q2Hb/mx-mod-0000.params"
# [01/02/2021 01:14:18 INFO 140066162063168] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1609550058.397469, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609550052.772826}
#
# [01/02/2021 01:14:18 INFO 140066162063168] #throughput_metric: host=algo-1, train throughput=35443.9761773 records/second
# [01/02/2021 01:14:18 WARNING 140066162063168] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/02/2021 01:14:18 WARNING 140066162063168] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-01-02 01:14:18.404] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2021-01-02 01:14:19.093] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 686, "num_examples": 200, "num_bytes": 33493152}
# [2021-01-02 01:14:19.830] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 663, "num_examples": 200, "num_bytes": 33493152}
# [01/02/2021 01:14:19 INFO 140066162063168] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.0038593374292870968)
# [01/02/2021 01:14:19 INFO 140066162063168] #train_score (algo-1) : ('binary_classification_accuracy', 0.9702754760137237)
# [01/02/2021 01:14:19 INFO 140066162063168] #train_score (algo-1) : ('binary_f_1.000', 0.0947143293614421)
# [01/02/2021 01:14:19 INFO 140066162063168] #train_score (algo-1) : ('precision', 0.04998387616897775)
# [01/02/2021 01:14:19 INFO 140066162063168] #train_score (algo-1) : ('recall', 0.9011627906976745)
# [01/02/2021 01:14:19 INFO 140066162063168] #train_score (algo-1) : ('roc_auc_score', 0.9778692409667837)
# [01/02/2021 01:14:19 INFO 140066162063168] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00385933742929
# [01/02/2021 01:14:19 INFO 140066162063168] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.970275476014
# [01/02/2021 01:14:19 INFO 140066162063168] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.0947143293614
# [01/02/2021 01:14:19 INFO 140066162063168] #quality_metric: host=algo-1, train precision <score>=0.049983876169
# [01/02/2021 01:14:19 INFO 140066162063168] #quality_metric: host=algo-1, train recall <score>=0.901162790698
# [01/02/2021 01:14:19 INFO 140066162063168] #quality_metric: host=algo-1, train roc_auc_score <score>=0.977869240967
# [01/02/2021 01:14:19 INFO 140066162063168] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [01/02/2021 01:14:19 INFO 140066162063168] Saved checkpoint to "/tmp/tmppwgc_H/mx-mod-0000.params"
# [01/02/2021 01:14:19 INFO 140066162063168] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 93214.22505378723, "sum": 93214.22505378723, "min": 93214.22505378723}, "finalize.time": {"count": 1, "max": 1491.779088973999, "sum": 1491.779088973999, "min": 1491.779088973999}, "initialize.time": {"count": 1, "max": 212.1720314025879, "sum": 212.1720314025879, "min": 212.1720314025879}, "check_early_stopping.time": {"count": 15, "max": 1.0221004486083984, "sum": 13.100862503051758, "min": 0.7970333099365234}, "setuptime": {"count": 1, "max": 24.35302734375, "sum": 24.35302734375, "min": 24.35302734375}, "update.time": {"count": 15, "max": 6608.876943588257, "sum": 91208.00042152405, "min": 5622.473955154419}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1609550059.894608, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1609549966.915437}
#
#
# 2021-01-02 01:14:32 Uploading - Uploading generated training model
# 2021-01-02 01:14:32 Completed - Training job completed
# Training seconds: 143
# Billable seconds: 143
# CPU times: user 774 ms, sys: 35.7 ms, total: 810 ms
# Wall time: 5min 12s

# %% [markdown]
# ### Deploy and evaluate the tuned estimator
#
# Deploy the tuned predictor and evaluate it.
#
# We hypothesized that a tuned model, optimized for a higher recall, would have fewer false negatives (fraudulent transactions incorrectly labeled as valid); did the number of false negatives get reduced after tuning the model?

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------------!CPU times: user 302 ms, sys: 18.3 ms, total: 320 ms
# Wall time: 8min 32s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# prediction (col)    0.0   1.0
# actual (row)
# 0.0               82659  2636
# 1.0                  10   138
#
# Recall:     0.932
# Precision:  0.050
# Accuracy:   0.969

# %% [markdown]
# ## Delete the endpoint
#
# As always, when you're done evaluating a model, you should delete the endpoint. Below, I'm using the `delete_endpoint` helper function I defined earlier.

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2021-01-02-01-14-46-631

# %% [markdown]
# ---
# ## Improvement: Managing Class Imbalance
#
# We have a model that is tuned to get a higher recall, which aims to reduce the number of false negatives. Earlier, we discussed how class imbalance may actually bias our model towards predicting that all transactions are valid, resulting in higher false negatives and true negatives. It stands to reason that this model could be further improved if we account for this imbalance.
#
# To account for class imbalance during training of a binary classifier, LinearLearner offers the hyperparameter, `positive_example_weight_mult`, which is the weight assigned to positive (1, fraudulent) examples when training a binary classifier. The weight of negative examples (0, valid) is fixed at 1.
#
# ### EXERCISE: Create a LinearLearner with a `positive_example_weight_mult` parameter
#
# In **addition** to tuning a model for higher recall (you may use `linear_recall` as a starting point), you should *add* a parameter that helps account for class imbalance. From the [hyperparameter documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) on `positive_example_weight_mult`, it reads:
# > "If you want the algorithm to choose a weight so that errors in classifying negative vs. positive examples have equal impact on training loss, specify `balanced`."
#
# You could also put in a specific float value, in which case you'd want to weight positive examples more heavily than negative examples, since there are fewer of them.

# %%
# instantiate a LinearLearner

# include params for tuning for higher recall
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              positive_example_weight_mult='balanced',
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### EXERCISE: Train the balanced estimator
#
# Fit the new, balanced estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_balanced.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-01-02 01:25:18 Starting - Starting the training job...
# 2021-01-02 01:25:20 Starting - Launching requested ML instancesProfilerReport-1609550717: InProgress
# ......
# 2021-01-02 01:26:41 Starting - Preparing the instances for training............
# 2021-01-02 01:28:44 Downloading - Downloading input data
# 2021-01-02 01:28:44 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [01/02/2021 01:28:48 INFO 139933965883200] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/02/2021 01:28:48 INFO 139933965883200] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'positive_example_weight_mult': u'balanced', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [01/02/2021 01:28:48 INFO 139933965883200] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [01/02/2021 01:28:48 WARNING 139933965883200] Loggers have already been setup.
# Process 1 is a worker.
# [01/02/2021 01:28:48 INFO 139933965883200] Using default worker.
# [01/02/2021 01:28:49 INFO 139933965883200] Checkpoint loading and saving are disabled.
# [2021-01-02 01:28:49.123] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 28, "num_examples": 1, "num_bytes": 168000}
# [01/02/2021 01:28:49 INFO 139933965883200] Create Store: local
# [2021-01-02 01:28:49.224] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 100, "num_examples": 11, "num_bytes": 1848000}
# [01/02/2021 01:28:49 INFO 139933965883200] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7
"Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.566899}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6600379360716546, "sum": 0.6600379360716546, "min": 0.6600379360716546}}, "EndTime": 1609551029.566964, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.566949}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1915235920815013, "sum": 1.1915235920815013, "min": 1.1915235920815013}}, "EndTime": 1609551029.567028, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.567016}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1962419752571452, "sum": 1.1962419752571452, "min": 1.1962419752571452}}, "EndTime": 1609551029.567096, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.567078}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1915238849889094, "sum": 1.1915238849889094, "min": 1.1915238849889094}}, "EndTime": 1609551029.567159, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.567141}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1962389244194607, "sum": 1.1962389244194607, "min": 1.1962389244194607}}, "EndTime": 1609551029.567219, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.567202}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.19769790910117, "sum": 1.19769790910117, "min": 1.19769790910117}}, "EndTime": 1609551029.567258, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.567249}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3364466894715274, "sum": 1.3364466894715274, "min": 1.3364466894715274}}, "EndTime": 1609551029.567307, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.567297}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1977039718244542, "sum": 1.1977039718244542, "min": 1.1977039718244542}}, "EndTime": 1609551029.567343, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.567335}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3364497312612869, "sum": 1.3364497312612869, "min": 1.3364497312612869}}, "EndTime": 1609551029.567388, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551029.567373}
#
# [01/02/2021 01:30:29 INFO 139933965883200] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.359280424722
# [01/02/2021 01:30:29 INFO 139933965883200] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.344260859811
# [01/02/2021 01:30:29 INFO 139933965883200] Epoch 14: Loss improved. Updating best model
# [01/02/2021 01:30:29 INFO 139933965883200] Saving model for epoch: 14
# [01/02/2021 01:30:29 INFO 139933965883200] Saved checkpoint to "/tmp/tmpWd5Bsk/mx-mod-0000.params"
# [01/02/2021 01:30:29 INFO 139933965883200] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1609551029.575725, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609551022.512383}
#
# [01/02/2021 01:30:29 INFO 139933965883200] #throughput_metric: host=algo-1, train throughput=28224.7825677 records/second
# [01/02/2021 01:30:29 WARNING 139933965883200] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/02/2021 01:30:29 WARNING 139933965883200] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-01-02 01:30:29.582] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2021-01-02 01:30:30.268] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 683, "num_examples": 200, "num_bytes": 33493152}
# [2021-01-02 01:30:31.071] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 731, "num_examples": 200, "num_bytes": 33493152}
# [01/02/2021 01:30:31 INFO 139933965883200] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.3330593371271228)
# [01/02/2021 01:30:31 INFO 139933965883200] #train_score (algo-1) : ('binary_classification_accuracy', 0.984054292650629)
# [01/02/2021 01:30:31 INFO 139933965883200] #train_score (algo-1) : ('binary_f_1.000', 0.16364114706656144)
# [01/02/2021 01:30:31 INFO 139933965883200] #train_score (algo-1) : ('precision', 0.08996239514029505)
# [01/02/2021 01:30:31 INFO 139933965883200] #train_score (algo-1) : ('recall', 0.9040697674418605)
# [01/02/2021 01:30:31 INFO 139933965883200] #train_score (algo-1) : ('roc_auc_score', 0.9878162005454635)
# [01/02/2021 01:30:31 INFO 139933965883200] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.333059337127
# [01/02/2021 01:30:31 INFO 139933965883200] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.984054292651
# [01/02/2021 01:30:31 INFO 139933965883200] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.163641147067
# [01/02/2021 01:30:31 INFO 139933965883200] #quality_metric: host=algo-1, train precision <score>=0.0899623951403
# [01/02/2021 01:30:31 INFO 139933965883200] #quality_metric: host=algo-1, train recall <score>=0.904069767442
# [01/02/2021 01:30:31 INFO 139933965883200] #quality_metric: host=algo-1, train roc_auc_score <score>=0.987816200545
# [01/02/2021 01:30:31 INFO 139933965883200] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [01/02/2021 01:30:31 INFO 139933965883200] Saved checkpoint to "/tmp/tmpwZZowD/mx-mod-0000.params"
# [01/02/2021 01:30:31 INFO 139933965883200] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 102357.27596282959, "sum": 102357.27596282959, "min": 102357.27596282959}, "finalize.time": {"count": 1, "max": 1550.5011081695557, "sum": 1550.5011081695557, "min": 1550.5011081695557}, "initialize.time": {"count": 1, "max": 325.253963470459, "sum": 325.253963470459, "min": 325.253963470459}, "check_early_stopping.time": {"count": 15, "max": 0.9968280792236328, "sum": 13.072967529296875, "min": 0.7619857788085938}, "setuptime": {"count": 1, "max": 111.40894889831543, "sum": 111.40894889831543, "min": 111.40894889831543}, "update.time": {"count": 15, "max": 7060.983896255493, "sum": 100092.03696250916, "min": 6142.928838729858}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1609551031.13642, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1609550929.09374}
#
#
# 2021-01-02 01:30:40 Uploading - Uploading generated training model
# 2021-01-02 01:30:40 Completed - Training job completed
# Training seconds: 135
# Billable seconds: 135
# CPU times: user 876 ms, sys: 53 ms, total: 929 ms
# Wall time: 5min 43s

# %% [markdown]
# ### EXERCISE: Deploy and evaluate the balanced estimator
#
# Deploy the balanced predictor and evaluate it. Do the results match with your expectations?

# %%
# %%time 
# deploy and create a predictor
balanced_predictor = linear_balanced.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------------!CPU times: user 313 ms, sys: 8.12 ms, total: 321 ms
# Wall time: 8min 32s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# prediction (col)    0.0   1.0
# actual (row)
# 0.0               83943  1352
# 1.0                  10   138
#
# Recall:     0.932
# Precision:  0.093
# Accuracy:   0.984

# %% [markdown]
# ## Delete the endpoint
#
# When you're done evaluating a model, you should delete the endpoint.

# %%
# delete the predictor endpoint 
delete_endpoint(balanced_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2021-01-02-01-31-01-152

# %% [markdown]
# A note on metric variability:
#
# The above model is tuned for the best possible precision with recall fixed at about 90%. The recall is fixed at 90% during training, but may vary when we apply our trained model to a test set of data.

# %% [markdown]
# ---
# ## Model Design
#
# Now that you've seen how to tune and balance a LinearLearner. Create, train and deploy your own model. This exercise is meant to be more open-ended, so that you get practice with the steps involved in designing a model and deploying it.
#
# ### EXERCISE: Train and deploy a LinearLearner with appropriate hyperparameters, according to the given scenario
#
# **Scenario:**
# * A bank has asked you to build a model that optimizes for a good user experience; users should only ever have up to about 15% of their valid transactions flagged as fraudulent.
#
# This requires that you make a design decision: Given the above scenario, what metric (and value) should you aim for during training?
#
# You may assume that performance on a training set will be within about 5-10% of the performance on a test set. For example, if you get 80% on a training set, you can assume that you'll get between about 70-90% accuracy on a test set.
#
# Your final model should account for class imbalance and be appropriately tuned.

# %%
# %%time
# instantiate and train a LinearLearner

# include params for tuning for higher precision
# *and* account for class imbalance in training data
linear_own = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              positive_example_weight_mult='balanced',
                              binary_classifier_model_selection_criteria='recall_at_target_precision', # target recall
                              target_precision=0.9) # 90% precision

linear_own.fit(formatted_train_data)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-01-02 02:06:35 Starting - Starting the training job...
# 2021-01-02 02:06:59 Starting - Launching requested ML instancesProfilerReport-1609553195: InProgress
# ......
# 2021-01-02 02:08:00 Starting - Preparing the instances for training.........
# 2021-01-02 02:09:31 Downloading - Downloading input data
# 2021-01-02 02:09:31 Training - Downloading the training image...
# 2021-01-02 02:10:01 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [01/02/2021 02:09:56 INFO 140065942136640] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/02/2021 02:09:56 INFO 140065942136640] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'target_precision': u'0.9', u'binary_classifier_model_selection_criteria': u'recall_at_target_precision', u'epochs': u'15', u'positive_example_weight_mult': u'balanced', u'mini_batch_size': u'1000'}
# [01/02/2021 02:09:56 INFO 140065942136640] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'recall_at_target_precision', u'use_lr_scheduler': u'true', u'target_precision': u'0.9', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [01/02/2021 02:09:56 WARNING 140065942136640] Loggers have already been setup.
# Process 1 is a worker.
# [01/02/2021 02:09:56 INFO 140065942136640] Using default worker.
# [01/02/2021 02:09:56 INFO 140065942136640] Checkpoint loading and saving are disabled.
# [2021-01-02 02:09:56.347] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 30, "num_examples": 1, "num_bytes": 168000}
# [01/02/2021 02:09:56 INFO 140065942136640] Create Store: local
# [2021-01-02 02:09:56.448] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 100, "num_examples": 11, "num_bytes": 1848000}
# [01/02/2021 02:09:56 INFO 140065942136640] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f634580ae50>
# [01/02/2021 02:09:56 INFO 140065942136640] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7562227e+04 1.8698826e+00 1.5398437e+00 1.4669231e+00 1.3983092e+00
#  1.3596656e+00 1.3372819e+00 1.2142768e+00 1.0664711e+00 1.0869697e+00
#  1.0642679e+00 1.0180734e+00 1.0014011e+00 9.9890339e-01 9.4154650e-01
#  9.0477407e-01 8.6453688e-01 8.3226335e-01 8.3712864e-01 8.1374246e-01
#  7.0363200e-01 6.9986749e-01 7.3282444e-01 5.9232694e-01 6.0836059e-01
#  5.2394670e-01 4.7785282e-01 3.8357860e-01 3.1198832e-01 2.3838838e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
#

#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1977931106030641, "sum": 1.1977931106030641, "min": 1.1977931106030641}}, "EndTime": 1609553409.808216, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1609553409.808198}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.415399354254181, "sum": 1.415399354254181, "min": 1.415399354254181}}, "EndTime": 1609553409.808287, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1609553409.808268}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4453688575322903, "sum": 1.4453688575322903, "min": 1.4453688575322903}}, "EndTime": 1609553409.808359, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1609553409.80834}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.406951865038081, "sum": 1.406951865038081, "min": 1.406951865038081}}, "EndTime": 1609553409.808419, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1609553409.808402}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.390485646770228, "sum": 1.390485646770228, "min": 1.390485646770228}}, "EndTime": 1609553409.808487, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1609553409.808469}
#
# [01/02/2021 02:10:09 INFO 140065942136640] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.486580406687
# [01/02/2021 02:10:09 INFO 140065942136640] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.434719873093
# [01/02/2021 02:10:09 INFO 140065942136640] Epoch 1: Loss improved. Updating best model
# [01/02/2021 02:10:09 INFO 140065942136640] Saving model for epoch: 1
# [01/02/2021 02:10:09 INFO 140065942136640] Saved checkpoint to "/tmp/tmpppNYsM/mx-mod-0000.params"
# [01/02/2021 02:10:09 INFO 140065942136640] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1609553409.816306, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1609553403.170678}
#
# [01/02/2021 02:10:09 INFO 140065942136640] #throughput_metric: host=algo-1, train throughput=29998.7487621 records/second
# [2021-01-02 02:10:16.055] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6237, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.43277541646526085, "sum": 0.43277541646526085, "min": 0.43277541646526085}}, "EndTime": 1609553416.05527, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055176}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39667804192777856, "sum": 0.39667804192777856, "min": 0.39667804192777856}}, "EndTime": 1609553416.055356, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055338}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.40689717355085975, "sum": 0.40689717355085975, "min": 0.40689717355085975}}, "EndTime": 1609553416.055422, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055404}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.40687298752674506, "sum": 0.40687298752674506, "min": 0.40687298752674506}}, "EndTime": 1609553416.055491, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055472}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5223801638732604, "sum": 0.5223801638732604, "min": 0.5223801638732604}}, "EndTime": 1609553416.055556, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055538}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6543291552558017, "sum": 0.6543291552558017, "min": 0.6543291552558017}}, "EndTime": 1609553416.055619, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055601}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5196175588099801, "sum": 0.5196175588099801, "min": 0.5196175588099801}}, "EndTime": 1609553416.055682, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055665}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6510918063063118, "sum": 0.6510918063063118, "min": 0.6510918063063118}}, "EndTime": 1609553416.055743, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055726}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4066697636896641, "sum": 0.4066697636896641, "min": 0.4066697636896641}}, "EndTime": 1609553416.055804, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055787}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4181338313117099, "sum": 0.4181338313117099, "min": 0.4181338313117099}}, "EndTime": 1609553416.055868, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.05585}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4261218985552764, "sum": 0.4261218985552764, "min": 0.4261218985552764}}, "EndTime": 1609553416.055934, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055916}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4122790199164769, "sum": 0.4122790199164769, "min": 0.4122790199164769}}, "EndTime": 1609553416.056013, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.055996}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5222357518373423, "sum": 0.5222357518373423, "min": 0.5222357518373423}}, "EndTime": 1609553416.056075, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056058}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6123303583423096, "sum": 0.6123303583423096, "min": 0.6123303583423096}}, "EndTime": 1609553416.056135, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056117}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5177965054919372, "sum": 0.5177965054919372, "min": 0.5177965054919372}}, "EndTime": 1609553416.056201, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056182}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6116577886073433, "sum": 0.6116577886073433, "min": 0.6116577886073433}}, "EndTime": 1609553416.056262, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056245}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5335500422338745, "sum": 0.5335500422338745, "min": 0.5335500422338745}}, "EndTime": 1609553416.056322, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056305}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5342875185252434, "sum": 0.5342875185252434, "min": 0.5342875185252434}}, "EndTime": 1609553416.056384, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056367}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5310742546349914, "sum": 0.5310742546349914, "min": 0.5310742546349914}}, "EndTime": 1609553416.056447, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056429}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.534265511134162, "sum": 0.534265511134162, "min": 0.534265511134162}}, "EndTime": 1609553416.056508, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056491}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6363912032237604, "sum": 0.6363912032237604, "min": 0.6363912032237604}}, "EndTime": 1609553416.056555, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056539}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6736034269860043, "sum": 0.6736034269860043, "min": 0.6736034269860043}}, "EndTime": 1609553416.056623, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056605}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6356398339583047, "sum": 0.6356398339583047, "min": 0.6356398339583047}}, "EndTime": 1609553416.056685, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056668}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6743056807398197, "sum": 0.6743056807398197, "min": 0.6743056807398197}}, "EndTime": 1609553416.05675, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056732}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1949283063878966, "sum": 1.1949283063878966, "min": 1.1949283063878966}}, "EndTime": 1609553416.056811, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056793}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.197745322069331, "sum": 1.197745322069331, "min": 1.197745322069331}}, "EndTime": 1609553416.056875, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056858}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1947962367378886, "sum": 1.1947962367378886, "min": 1.1947962367378886}}, "EndTime": 1609553416.056934, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056917}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.197764569919912, "sum": 1.197764569919912, "min": 1.197764569919912}}, "EndTime": 1609553416.056994, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.056978}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2846235080124744, "sum": 1.2846235080124744, "min": 1.2846235080124744}}, "EndTime": 1609553416.057052, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.057036}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4144121550746898, "sum": 1.4144121550746898, "min": 1.4144121550746898}}, "EndTime": 1609553416.05711, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.057094}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2821394164118936, "sum": 1.2821394164118936, "min": 1.2821394164118936}}, "EndTime": 1609553416.05717, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.057153}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4429454690751118, "sum": 1.4429454690751118, "min": 1.4429454690751118}}, "EndTime": 1609553416.057222, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609553416.057211}
#
# [01/02/2021 02:10:16 INFO 140065942136640] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.432775416465
# [01/02/2021 02:10:16 INFO 140065942136640] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.396678041928
# [01/02/2021 02:10:16 INFO 140065942136640] Epoch 2: Loss improved. Updating best model
# [01/02/2021 02:10:16 INFO 140065942136640] Saving model for epoch: 2
# [01/02/2021 02:10:16 INFO 140065942136640] Saved checkpoint to "/tmp/tmpcZRn1J/mx-mod-0000.params"
# [01/02/2021 02:10:16 INFO 140065942136640] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1609553416.06525, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1
"Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609553493.215023}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1915238849889094, "sum": 1.1915238849889094, "min": 1.1915238849889094}}, "EndTime": 1609553493.2151, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609553493.215082}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1962389244194607, "sum": 1.1962389244194607, "min": 1.1962389244194607}}, "EndTime": 1609553493.215161, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609553493.215144}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.19769790910117, "sum": 1.19769790910117, "min": 1.19769790910117}}, "EndTime": 1609553493.215222, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609553493.215204}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3364466894715274, "sum": 1.3364466894715274, "min": 1.3364466894715274}}, "EndTime": 1609553493.215285, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609553493.215267}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1977039718244542, "sum": 1.1977039718244542, "min": 1.1977039718244542}}, "EndTime": 1609553493.215348, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609553493.215331}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3364497312612869, "sum": 1.3364497312612869, "min": 1.3364497312612869}}, "EndTime": 1609553493.21541, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609553493.215392}
#
# [01/02/2021 02:11:33 INFO 140065942136640] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.359280424722
# [01/02/2021 02:11:33 INFO 140065942136640] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.344260859811
# [01/02/2021 02:11:33 INFO 140065942136640] Epoch 14: Loss improved. Updating best model
# [01/02/2021 02:11:33 INFO 140065942136640] Saving model for epoch: 14
# [01/02/2021 02:11:33 INFO 140065942136640] Saved checkpoint to "/tmp/tmpAzG4po/mx-mod-0000.params"
# [01/02/2021 02:11:33 INFO 140065942136640] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1609553493.223177, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609553487.176092}
#
# [01/02/2021 02:11:33 INFO 140065942136640] #throughput_metric: host=algo-1, train throughput=32967.9580808 records/second
# [01/02/2021 02:11:33 WARNING 140065942136640] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/02/2021 02:11:33 WARNING 140065942136640] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-01-02 02:11:33.230] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2021-01-02 02:11:33.832] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 598, "num_examples": 200, "num_bytes": 33493152}
# [2021-01-02 02:11:34.641] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 737, "num_examples": 200, "num_bytes": 33493152}
# [01/02/2021 02:11:34 INFO 140065942136640] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.3330593371271228)
# [01/02/2021 02:11:34 INFO 140065942136640] #train_score (algo-1) : ('binary_classification_accuracy', 0.9993880540117573)
# [01/02/2021 02:11:34 INFO 140065942136640] #train_score (algo-1) : ('binary_f_1.000', 0.8168168168168168)
# [01/02/2021 02:11:34 INFO 140065942136640] #train_score (algo-1) : ('precision', 0.84472049689441)
# [01/02/2021 02:11:34 INFO 140065942136640] #train_score (algo-1) : ('recall', 0.7906976744186046)
# [01/02/2021 02:11:34 INFO 140065942136640] #train_score (algo-1) : ('roc_auc_score', 0.9878162005454635)
# [01/02/2021 02:11:34 INFO 140065942136640] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.333059337127
# [01/02/2021 02:11:34 INFO 140065942136640] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.999388054012
# [01/02/2021 02:11:34 INFO 140065942136640] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.816816816817
# [01/02/2021 02:11:34 INFO 140065942136640] #quality_metric: host=algo-1, train precision <score>=0.844720496894
# [01/02/2021 02:11:34 INFO 140065942136640] #quality_metric: host=algo-1, train recall <score>=0.790697674419
# [01/02/2021 02:11:34 INFO 140065942136640] #quality_metric: host=algo-1, train roc_auc_score <score>=0.987816200545
# [01/02/2021 02:11:34 INFO 140065942136640] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [01/02/2021 02:11:34 INFO 140065942136640] Saved checkpoint to "/tmp/tmpVoABOA/mx-mod-0000.params"
# [01/02/2021 02:11:34 INFO 140065942136640] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 98696.53105735779, "sum": 98696.53105735779, "min": 98696.53105735779}, "finalize.time": {"count": 1, "max": 1472.6519584655762, "sum": 1472.6519584655762, "min": 1472.6519584655762}, "initialize.time": {"count": 1, "max": 322.44420051574707, "sum": 322.44420051574707, "min": 322.44420051574707}, "check_early_stopping.time": {"count": 15, "max": 0.9911060333251953, "sum": 12.759208679199219, "min": 0.762939453125}, "setuptime": {"count": 1, "max": 24.682044982910156, "sum": 24.682044982910156, "min": 24.682044982910156}, "update.time": {"count": 15, "max": 7142.250776290894, "sum": 96520.96676826477, "min": 6044.656991958618}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1609553494.706236, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1609553396.315754}
#
#
# 2021-01-02 02:12:03 Uploading - Uploading generated training model
# 2021-01-02 02:12:03 Completed - Training job completed
# ProfilerReport-1609553195: NoIssuesFound
# Training seconds: 143
# Billable seconds: 143
# CPU times: user 848 ms, sys: 36.4 ms, total: 884 ms
# Wall time: 5min 43s

# %%
# %%time 
# deploy and evaluate a predictor
linear_own_deployed = linear_own.deploy(initial_instance_count=1, instance_type='ml.t2.medium')

print('Metrics for own, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(linear_own_deployed, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------------!Metrics for own, LinearLearner.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# prediction (col)    0.0  1.0
# actual (row)
# 0.0               85262   33
# 1.0                  28  120
#
# Recall:     0.811
# Precision:  0.784
# Accuracy:   0.999
#
# CPU times: user 6.67 s, sys: 71 ms, total: 6.75 s
# Wall time: 8min 45s

# %%
## IMPORTANT
# delete the predictor endpoint after evaluation 
delete_endpoint(linear_own_deployed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-878746427686> in <module>
#       1 ## IMPORTANT
#       2 # delete the predictor endpoint after evaluation
# ----> 3 delete_endpoint(linear_own_deployed)
#
# NameError: name 'linear_own_deployed' is not defined

# %% [markdown]
# ## Final Cleanup!
#
# * Double check that you have deleted all your endpoints.
# * I'd also suggest manually deleting your S3 bucket, models, and endpoint configurations directly from your AWS console.
#
# You can find thorough cleanup instructions, [in the documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html).

# %% [markdown]
# ---
# # Conclusion
#
# In this notebook, you saw how to train and deploy a LinearLearner in SageMaker. This model is well-suited for a binary classification task that involves specific design decisions and managing class imbalance in the training set.
#
# Following the steps of a machine learning workflow, you loaded in some credit card transaction data, explored that data and prepared it for model training. Then trained, deployed, and evaluated several models, according to different design considerations!
